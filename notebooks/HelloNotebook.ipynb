# %%
#imports for the entire python notebook.

import math

import matplotlib.pyplot as plt
import numpy
import scipy

# %%
demodata = [0, 1, 2, 3, 4, 5]
demoy = [9, 4, 1, 4, 9, 16]

fig, axes = plt.subplots()
axes.plot(demodata, demoy)

# %%
values = [math.sin(math.pi * .1 * x) for x in range(100)]
axes.plot(values)
